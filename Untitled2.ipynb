# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhusudhanKosari/farmsyncro/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Mjt4uOZV1iMkPfBQy5HH")
project = rf.workspace("joseph-nelson").project("plantdoc")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PlantDoc-4 in yolov8:: 100%|██████████| 5150/5150 [00:01<00:00, 3066.76it/s]

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.5/913.5 kB 53.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(data='PlantDoc-4/data.yaml',epochs=100,batch=16)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model= YOLO('yolov8n.pt')

results=model.predict(source="/content/PlantDoc-4/test/images",save=True,stream=True)

for result in results:
  pass
# Out:
# image 1/246 /content/PlantDoc-4/test/images/-2320-Bacterial-Spot-and-Speck_jpg.rf.9d63c6e88cb474baa4d4eab1681f6d41.jpg: 480x640 1 apple, 44.8ms
# image 2/246 /content/PlantDoc-4/test/images/0000_jpg.rf.d9be28abba2b4e67431ed005bdde14de.jpg: 640x640 1 umbrella, 8.7ms
# image 3/246 /content/PlantDoc-4/test/images/000_jpg.rf.e32ba3f04d1e855e58b1b3f5475cf1e5.jpg: 480x640 1 person, 7.2ms
# image 4/246 /content/PlantDoc-4/test/images/00_jpg.rf.567521ea9c2d0153cb8b96c5bd18e692.jpg: 480x640 (no detections), 6.5ms
# image 5/246 /content/PlantDoc-4/test/images/00pe_jpg.rf.a17680fc7cdfa4c78c70f3ef1a81fd79.jpg: 640x480 (no detections), 39.4ms
# image 6/246 /content/PlantDoc-4/test/images/01_jpg.rf.132567152237e39d0c9a6f61dfc88873.jpg: 512x640 (no detections), 38.6ms
# image 7/246 /content/PlantDoc-4/test/images/02_-Rust-2017-207u24s_jpg.rf.f1a95c4ac228e45d9b83a977e967d31e.jpg: 384x640 (no detections), 41.0ms
# ...
